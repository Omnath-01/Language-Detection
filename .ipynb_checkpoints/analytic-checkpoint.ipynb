# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")

# %%
# Loading the dataset
data = pd.read_csv("Language Detection.csv")

# %%
# value count for each language
data["Language"].value_counts()
# Out:
# Language
# English       1385
# French        1014
# Spanish        819
# Portugeese     739
# Italian        698
# Russian        692
# Sweedish       676
# Malayalam      594
# Dutch          546
# Arabic         536
# Turkish        474
# German         470
# Tamil          469
# Danish         428
# Kannada        369
# Greek          365
# Hindi           63
# Name: count, dtype: int64

# %%
# separating the independent and dependant features
X = data["Text"]
y = data["Language"]

# %%
# converting categorical variables to numerical
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# creating a list for appending the preprocessed text
data_list = []

# %%
# iterating through all the text
for text in X:
    # removing the symbols and numbers
    text = re.sub(r'[!@#$(),n"%^*?:;~`0-9]', ' ', text)
    text = re.sub(r'[[]]', ' ', text)
    # converting the text to lower case
    text = text.lower()
    # appending to data_list
    data_list.append(text)

# %%
# creating bag of words using countvectorizer
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(data_list).toarray()

# %%
#train test splitting
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
#model creation and predict
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
# predict 
y_pred = model.predict(x_test)

# %%
# model evaluation
from sklearn.metrics import accuracy_score, confusion_matrix
ac = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

# %%
ac
# Out:
# 0.9772727272727273

# %%
# visualising the confusion matrix
plt.figure(figsize=(15,10))
sns.heatmap(cm, annot = True)
plt.show()

# %%
# English
model.predict("I love programming, Python is my favorite language.")
# French
predict("J'adore programmer, Python est mon langage préféré.")
# Spanish
predict("Me encanta programar, Python es mi lenguaje favorito.")
# Portugeese
predict("Eu amo programar, Python é minha linguagem favorita.")
# Italian
predict("Amo programmare, Python è il mio linguaggio preferito.")
# Russian
predict("Я люблю программировать, Python — мой любимый язык.")
# Sweedish
predict("Jag älskar programmering, Python är mitt favoritspråk.")
# Malayalam
predict("എനിക്ക് പ്രോഗ്രാമിംഗ് ഇഷ്ടമാണ്, പൈത്തൺ എന്റെ പ്രിയപ്പെട്ട ഭാഷയാണ്.")
# Dutch
predict("Ik hou van programmeren, Python is mijn favoriete taal.")
# Arabic
predict("أحب البرمجة ، بايثون هي لغتي المفضلة.")
# Turkish
predict("Programlamayı seviyorum, Python benim favori dilim.")
# German
predict("Ich liebe das Programmieren, Python ist meine Lieblingssprache.")
# Tamil
predict("நான் நிரலாக்கத்தை விரும்புகிறேன், பைதான் எனக்கு மிகவும் பிடித்த மொழி.")
# Danish
predict("Jeg elsker programmering, Python er mit yndlingssprog.")
# Kannada
predict(
    "ನಾನು ಪ್ರೋಗ್ರಾಮಿಂಗ್ ಅನ್ನು ಇಷ್ಟಪಡುತ್ತೇನೆ, ಪೈಥಾನ್ ನನ್ನ ನೆಚ್ಚಿನ ಭಾಷೆಯಾಗಿದೆ.")
# Greek
predict("Λατρεύω τον προγραμματισμό, η Python είναι η αγαπημένη μου γλώσσα.")
# Hindi
predict("मुझे प्रोग्रामिंग पसंद है, पायथन मेरी पसंदीदा भाषा है।")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # English
# ----> 2 model.predict("I love programming, Python is my favorite language.")
#       3 # French
#       4 predict("J'adore programmer, Python est mon langage préféré.")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\naive_bayes.py:105, in _BaseNB.predict(self, X)
#      91 """
#      92 Perform classification on an array of test vectors X.
#      93
#    (...)
#     102     Predicted target values for X.
#     103 """
#     104 check_is_fitted(self)
# --> 105 X = self._check_X(X)
#     106 jll = self._joint_log_likelihood(X)
#     107 return self.classes_[np.argmax(jll, axis=1)]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\naive_bayes.py:579, in _BaseDiscreteNB._check_X(self, X)
#     577 def _check_X(self, X):
# ...
